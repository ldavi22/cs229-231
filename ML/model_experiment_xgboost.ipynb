# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from feature_eng import preprocess

df = pd.read_csv("~/ML/Data/house_prices/train.csv")
x_train, x_test = train_test_split(df,test_size=0.8,random_state=42)
x_train,x_test,y_train,y_test = preprocess(x_train,x_test)

# %% [markdown]
# We have overfit data

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV,KFold

kf = KFold(5, shuffle=True, random_state=42)

param_grid = {
    'max_depth' : [3,4,5,6],
    'min_child_weight' : [1,3,5],
    'subsample' : [0.7,0.8,0.9],
    'colsample_bytree' : [0.6,0.8,1.0],
    'reg_alpha' : [0,0.1,0.5],
    'reg_lambda' : [0.5,1.0,2.0],
    'gamma': [0,0.1,0.5],
}

base_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=500,
    learning_rate=0.05,
    random_state=42,
    n_jobs=-1,
)

grid = RandomizedSearchCV(
    base_model,
    param_grid,
    n_iter=500,
    cv=kf,
    scoring='neg_root_mean_squared_error',
    verbose=2,
    return_train_score=True,
    n_jobs=-1,
)

result = grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV] END colsample_bytree=1.0, gamma=0.5, max_depth=5, min_child_weight=5, reg_alpha=0.1, reg_lambda=2.0, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=1.0, gamma=0.5, max_depth=5, min_child_weight=5, reg_alpha=0.1, reg_lambda=2.0, subsample=0.9; total time=   1.1s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=4, min_child_weight=3, reg_alpha=0.1, reg_lambda=0.5, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=4, min_child_weight=3, reg_alpha=0.1, reg_lambda=0.5, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=4, min_child_weight=3, reg_alpha=0.1, reg_lambda=0.5, subsample=0.8; total time=   0.4s
# [CV] END colsample_bytree=0.6, gamma=0.5, max_depth=3, min_child_weight=5, reg_alpha=0.1, reg_lambda=0.5, subsample=0.7; total time=   0.3s
# ...

# %%
from logging_helper import log

log(x_train,y_train,x_test,y_test,result,"XGBoost")
# Out:
# Initialized MLflow to track repo "ldavi22/cs229-231"
# Repository ldavi22/cs229-231 initialized!
# 🏃 View run XGBoost at: https://dagshub.com/ldavi22/cs229-231.mlflow/#/experiments/1/runs/05a7485e0b9249428f6846945a68511c
# 🧪 View experiment at: https://dagshub.com/ldavi22/cs229-231.mlflow/#/experiments/1

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV,KFold

kf = KFold(5, shuffle=True, random_state=42)

param_grid = {
    'max_depth' : [3,4,5,6],
    'min_child_weight' : [1,3,5],
    'subsample' : [0.7,0.8,0.9],
    'colsample_bytree' : [0.6,0.8,1.0],
    'reg_alpha' : [0,0.1,0.5],
    'reg_lambda' : [0.5,1.0,2.0],
    'gamma': [0,0.1,0.5],
}

base_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=200,
    learning_rate=0.05,
    random_state=42,
    n_jobs=-1,
)

grid = RandomizedSearchCV(
    base_model,
    param_grid,
    n_iter=50,
    cv=kf,
    scoring='neg_root_mean_squared_error',
    verbose=2,
    return_train_score=True,
    n_jobs=-1,
)

result = grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=3, min_child_weight=1, reg_alpha=0, reg_lambda=2.0, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=3, min_child_weight=1, reg_alpha=0, reg_lambda=2.0, subsample=0.9; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=4, min_child_weight=3, reg_alpha=0, reg_lambda=2.0, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=4, min_child_weight=3, reg_alpha=0, reg_lambda=2.0, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=3, min_child_weight=1, reg_alpha=0, reg_lambda=2.0, subsample=0.9; total time=   0.4s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=3, min_child_weight=1, reg_alpha=0, reg_lambda=2.0, subsample=0.9; total time=   0.4s
# ...

# %%
from logging_helper import log

log(x_train,y_train,x_test,y_test,result,"XGBoost")
# Out:
# Initialized MLflow to track repo "ldavi22/cs229-231"
# Repository ldavi22/cs229-231 initialized!
# 🏃 View run XGBoost at: https://dagshub.com/ldavi22/cs229-231.mlflow/#/experiments/1/runs/aab8bad4e81c4a4f95f7a0bfe59fb6ab
# 🧪 View experiment at: https://dagshub.com/ldavi22/cs229-231.mlflow/#/experiments/1

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV,KFold

kf = KFold(5, shuffle=True, random_state=42)

param_grid = {
    'max_depth' : [3,4,5,6],
    'min_child_weight' : [1,3,5],
    'subsample' : [0.7,0.8,0.9],
    'colsample_bytree' : [0.6,0.8,1.0],
    'reg_alpha' : [0,0.1,0.5],
    'reg_lambda' : [0.5,1.0,2.0],
    'gamma': [0,0.1,0.5],
}

base_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=15,
    learning_rate=0.05,
    random_state=42,
    n_jobs=-1,
)

grid = RandomizedSearchCV(
    base_model,
    param_grid,
    n_iter=30,
    cv=kf,
    scoring='neg_root_mean_squared_error',
    verbose=2,
    return_train_score=True,
    n_jobs=-1,
)

result = grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=3, min_child_weight=5, reg_alpha=0, reg_lambda=1.0, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=3, min_child_weight=5, reg_alpha=0, reg_lambda=1.0, subsample=0.9; total time=   1.1s
# [CV] END colsample_bytree=0.6, gamma=0.5, max_depth=6, min_child_weight=5, reg_alpha=0.5, reg_lambda=1.0, subsample=0.9; total time=   1.0s
# [CV] END colsample_bytree=0.8, gamma=0, max_depth=3, min_child_weight=1, reg_alpha=0.1, reg_lambda=0.5, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0, max_depth=3, min_child_weight=1, reg_alpha=0.1, reg_lambda=0.5, subsample=0.8; total time=   0.3s
# [CV] END colsample_bytree=0.8, gamma=0.1, max_depth=5, min_child_weight=3, reg_alpha=0.1, reg_lambda=0.5, subsample=0.9; total time=   0.1s
# ...

# %%
from logging_helper import log

log(x_train,y_train,x_test,y_test,result,"XGBoost with 15 estimators ")
# Out:
# Initialized MLflow to track repo "ldavi22/cs229-231"
# Repository ldavi22/cs229-231 initialized!
# 🏃 View run XGBoost with 15 estimators  at: https://dagshub.com/ldavi22/cs229-231.mlflow/#/experiments/1/runs/84189bfe973d497ab7bf3092adca9e1b
# 🧪 View experiment at: https://dagshub.com/ldavi22/cs229-231.mlflow/#/experiments/1

# %%
import xgboost as xgb
from sklearn.model_selection import RandomizedSearchCV,KFold,GridSearchCV

kf = KFold(5, shuffle=True, random_state=42)

param_grid = {
    'max_depth' : [3,4,5,6],
    'min_child_weight' : [5,7,9,10],
    'subsample' : [0.7,0.8,0.9],
    'colsample_bytree' : [0.6,0.8,1.0],
    'reg_alpha' : [0,0.1,0.5,0.7,0.9,1],
    'reg_lambda' : [0.5,1.0,2.0,3,4,5],
    'gamma': [0,0.1,0.5,1,2,5],
}

base_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=35,
    learning_rate=0.05,
    random_state=42,
    n_jobs=-1,
)

grid = RandomizedSearchCV(
    base_model,
    param_grid,
    n_iter=500,
    cv=kf,
    scoring='neg_root_mean_squared_error',
    verbose=2,
    return_train_score=True,
    n_jobs=-1,
)

result = grid.fit(x_train,y_train)
# Out:
# Fitting 5 folds for each of 500 candidates, totalling 2500 fits
# [CV] END colsample_bytree=0.8, gamma=0, max_depth=3, min_child_weight=7, reg_alpha=0, reg_lambda=4, subsample=0.9; total time=   0.6s
# [CV] END colsample_bytree=0.6, gamma=0, max_depth=5, min_child_weight=9, reg_alpha=0.9, reg_lambda=0.5, subsample=0.8; total time=   0.2s
# [CV] END colsample_bytree=0.6, gamma=0, max_depth=5, min_child_weight=9, reg_alpha=0.9, reg_lambda=0.5, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=0, max_depth=5, min_child_weight=9, reg_alpha=0.9, reg_lambda=0.5, subsample=0.8; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=2, max_depth=5, min_child_weight=7, reg_alpha=0.5, reg_lambda=3, subsample=0.9; total time=   0.1s
# [CV] END colsample_bytree=0.6, gamma=2, max_depth=5, min_child_weight=7, reg_alpha=0.5, reg_lambda=3, subsample=0.9; total time=   0.1s
# ...

# %%
from logging_helper import log

log(x_train,y_train,x_test,y_test,result,"XGBoost v3")
# Out:
# Initialized MLflow to track repo "ldavi22/cs229-231"
# Repository ldavi22/cs229-231 initialized!
# 🏃 View run XGBoost v3 at: https://dagshub.com/ldavi22/cs229-231.mlflow/#/experiments/1/runs/c8948584e7b242fdabd11a4216bdc9a5
# 🧪 View experiment at: https://dagshub.com/ldavi22/cs229-231.mlflow/#/experiments/1

# %% [markdown]
# ## Without CV

# %%
xgb_model = xgb.XGBRegressor(
    objective='reg:squarederror',
    n_estimators=2000,          # set high, early stopping will cut it
    learning_rate=0.05,
    max_depth=4,
    subsample=0.8,
    colsample_bytree=0.8,
    min_child_weight=3,
    early_stopping_rounds=50,   # stop if no improvement for 50 rounds
    eval_metric='rmse',
    random_state=42,
    n_jobs=-1
)

xgb_model.fit(
    x_train, y_train,
    eval_set=[(x_test, y_test)],
    verbose=100                 # print every 100 rounds
)

print(f"Best iteration: {xgb_model.best_iteration}")
# Out:
# [0]	validation_0-rmse:0.39314
# [100]	validation_0-rmse:0.15096
# [200]	validation_0-rmse:0.14854
# [220]	validation_0-rmse:0.14846
# Best iteration: 170

# %% [markdown]
# ## Using Optuna

# %%
import optuna
import xgboost as xgb_model
from sklearn.model_selection import KFold
from sklearn.metrics import root_mean_squared_error
import numpy as np

def objective(trial):
    params = {
        'n_estimators' : trial.suggest_int('n_estimators', 100, 1000),
        'max_depth' : trial.suggest_int('max_depth', 3, 10),
        'learning_rate' : trial.suggest_float('learning_rate', 0.1, 1.0,log=True),
        'subsample' : trial.suggest_float('subsample', 0.5, 1.0),
        'colsample_bytree' : trial.suggest_float('colsample_bytree', 0.5, 1.0),
        'min_child_weight' : trial.suggest_int('min_child_weight', 1, 10),
        'reg_alpha' : trial.suggest_float('reg_alpha', 0.1, 10,log=True),
        'reg_lambda' : trial.suggest_float('reg_lambda', 0.1, 10,log=True),
    }

    kf = KFold(n_splits=5, shuffle=True, random_state=42)
    val_scores = []

    for train_idx,val_idx in kf.split(x_train):
        x_tr,x_val = x_train.iloc[train_idx],x_train.iloc[val_idx]
        y_tr,y_val = y_train.iloc[train_idx],y_train.iloc[val_idx]

        model = xgb.XGBRegressor(**params,random_state=42,versobity = 0)

        model.fit(
            x_tr,y_tr,
            eval_set=[(x_val,y_val)],
            verbose=False,
        )

        pred = model.predict(x_val)
        rmse = root_mean_squared_error(y_val, pred)
        val_scores.append(rmse)
    return np.mean(val_scores)

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=100,show_progress_bar=True)

print(f'Best val RMSE: {study.best_value:.4f}')
print(f'Best params: {study.best_params}')
# Out:
# [I 2026-04-12 16:42:36,573] A new study created in memory with name: no-name-53499d07-4ba7-4e33-bd6a-f2b99ed54719
#   0%|          | 0/100 [00:00<?, ?it/s]/home/ldavi/.local/lib/python3.14/site-packages/xgboost/training.py:200: UserWarning: [16:42:36] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "versobity" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/ldavi/.local/lib/python3.14/site-packages/xgboost/training.py:200: UserWarning: [16:42:51] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "versobity" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /home/ldavi/.local/lib/python3.14/site-packages/xgboost/training.py:200: UserWarning: [16:43:41] WARNING: /__w/xgboost/xgboost/src/learner.cc:782:
# Parameters: { "versobity" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...

# %%
print(study.best_params)
# Out:
# {'n_estimators': 265, 'max_depth': 10, 'learning_rate': 0.10063678534165821, 'subsample': 0.6495332477424941, 'colsample_bytree': 0.5273960268045789, 'min_child_weight': 6, 'reg_alpha': 0.15365230434587626, 'reg_lambda': 8.727575394726044}

# %%
best_model = xgb.XGBRegressor(**study.best_params, random_state=42,verbosity=0)
best_model.fit(x_train,y_train)

train_pred = best_model.predict(x_train)
test_pred = best_model.predict(x_test)
train_rmse = root_mean_squared_error(y_train, train_pred)
test_rmse = root_mean_squared_error(y_test, test_pred)

print(f'Train RMSE: {train_rmse:.4f}')
print(f'Test RMSE:  {test_rmse:.4f}')
# Out:
# Train RMSE: 0.0243
# Test RMSE:  0.1497

# %%
params = {
    'n_estimators': 265,
    'max_depth': 4,
    'learning_rate': 0.10063678534165821,
    'subsample': 0.6495332477424941,
    'colsample_bytree': 0.5273960268045789,
    'min_child_weight': 6,
    'reg_alpha': 0.15365230434587626,
    'reg_lambda': 8.727575394726434,
}

final_model = xgb.XGBRegressor(
    **params,
    random_state=42,
)

final_model.fit(
    x_train,
    y_train,
    eval_set=[(x_test, y_test)],
    verbose=True
)
# Out:
# [0]	validation_0-rmse:0.38722
# [1]	validation_0-rmse:0.37054
# [2]	validation_0-rmse:0.35630
# [3]	validation_0-rmse:0.34037
# [4]	validation_0-rmse:0.32627
# [5]	validation_0-rmse:0.31214
# [6]	validation_0-rmse:0.30012
# [7]	validation_0-rmse:0.28937
# [8]	validation_0-rmse:0.28089
# [9]	validation_0-rmse:0.27122
# [10]	validation_0-rmse:0.26307
# [11]	validation_0-rmse:0.25587
# [12]	validation_0-rmse:0.24853
# [13]	validation_0-rmse:0.24114
# [14]	validation_0-rmse:0.23447
# [15]	validation_0-rmse:0.22939
# [16]	validation_0-rmse:0.22498
# [17]	validation_0-rmse:0.22079
# [18]	validation_0-rmse:0.21670
# [19]	validation_0-rmse:0.21236
# [20]	validation_0-rmse:0.20905
# [21]	validation_0-rmse:0.20641
# [22]	validation_0-rmse:0.20356
# [23]	validation_0-rmse:0.20025
# [24]	validation_0-rmse:0.19756
# [25]	validation_0-rmse:0.19532
# [26]	validation_0-rmse:0.19361
# [27]	validation_0-rmse:0.19143
# [28]	validation_0-rmse:0.18981
# [29]	validation_0-rmse:0.18842
# ...

# %%
from sklearn.metrics import mean_squared_error
train_preds = final_model.predict(x_train)
train_rmse = np.sqrt(mean_squared_error(y_train, train_preds))
print(f"Train RMSE: {train_rmse:.4f}")
# Out:
# Train RMSE: 0.0318
